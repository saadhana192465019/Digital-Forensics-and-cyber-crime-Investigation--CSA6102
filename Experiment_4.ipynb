# %% [markdown]
# <a href="https://colab.research.google.com/github/saadhana192465019/Digital-Forensics-and-cyber-crime-Investigation--CSA6102/blob/main/Experiment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import socket

# Get domain name from user
domain = input("Enter the domain name: ")

try:
    # Perform DNS lookup
    ip_address = socket.gethostbyname(domain)

    print("\nDNS Lookup Result")
    print("-----------------")
    print("Domain Name :", domain)
    print("IP Address  :", ip_address)

except socket.gaierror:
    print("\nError: Unable to resolve the domain name.")
# Out:
# Enter the domain name: www.google.com
#
# DNS Lookup Result
# -----------------
# Domain Name : www.google.com
# IP Address  : 142.251.152.119
