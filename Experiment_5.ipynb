# %% [markdown]
# <a href="https://colab.research.google.com/github/saadhana192465019/Digital-Forensics-and-cyber-crime-Investigation--CSA6102/blob/main/Experiment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Digital Forensic Investigation Report Generator

case_name = input("Enter Case Name: ")
investigator = input("Enter Investigator Name: ")
evidence = input("Enter Evidence Description: ")

print("\n" + "=" * 50)
print("      DIGITAL FORENSIC INVESTIGATION REPORT")
print("=" * 50)

print("\nCase Name      :", case_name)
print("Investigator   :", investigator)
print("Evidence       :", evidence)

print("\n1. Identification")
print("   - Digital evidence identified and documented.")

print("\n2. Preservation")
print("   - Evidence secured to prevent modification.")

print("\n3. Collection")
print("   - Evidence collected using forensic procedures.")

print("\n4. Examination and Analysis")
print("   - Evidence examined and analyzed for relevant information.")

print("\n5. Reporting")
print("   - Investigation findings documented successfully.")

print("\n" + "=" * 50)
print("Investigation Lifecycle Completed Successfully.")
print("=" * 50)
# Out:
# Enter Case Name: Email Fraud Case
# Enter Investigator Name: saadhana
# Enter Evidence Description: Suspected phishing email and system logs
#
# ...
#       DIGITAL FORENSIC INVESTIGATION REPORT
# ...
#
# Case Name      : Email Fraud Case
# Investigator   : saadhana
# Evidence       : Suspected phishing email and system logs
#
# 1. Identification
#    - Digital evidence identified and documented.
#
# 2. Preservation
#    - Evidence secured to prevent modification.
#
# 3. Collection
#    - Evidence collected using forensic procedures.
#
# 4. Examination and Analysis
#    - Evidence examined and analyzed for relevant information.
#
# 5. Reporting
#    - Investigation findings documented successfully.
#
# ...
# Investigation Lifecycle Completed Successfully.
# ...
